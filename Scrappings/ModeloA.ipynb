# %%
# !pip install yfinance numpy pandas seabron scikit-learn optuna seaborn xgboost joblib
# Out:
# Requirement already satisfied: yfinance in c:\users\alexi\appdata\local\programs\python\python314\lib\site-packages (0.2.66)
# Requirement already satisfied: numpy in c:\users\alexi\appdata\local\programs\python\python314\lib\site-packages (2.3.5)
# Requirement already satisfied: pandas in c:\users\alexi\appdata\local\programs\python\python314\lib\site-packages (2.3.3)
# ERROR: Could not find a version that satisfies the requirement seabron (from versions: none)
# ERROR: No matching distribution found for seabron

# %%
import yfinance as yf
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.feature_selection import mutual_info_classif, chi2
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import optuna
import warnings
import xgboost as xgb
from sklearn.metrics import accuracy_score, precision_score
from sklearn.model_selection import train_test_split
import joblib

# %% [markdown]
# <div style="
#     font-size: 0.85em;
#     color: #c9c9c9;
#     border-left: 3px solid #555;
#     padding-left: 12px;
#     margin-top: 10px;
# ">
#
# <b>Ativo de Teste — Itaú (Mapeamento Inicial de Features)</b><br>
# Selecionado como ativo de referência para validação e mapeamento completo das features iniciais do modelo.
# Todos os testes a seguir servirão de base para o **Modelo A**, no qual essas etapas serão automatizadas, incluindo **engenharia de dados** e **tratamento de features**.
#
# <br><br>
# <b>I) Dados de Preço e Volume</b>
# <ul>
#   <li>Preço de Abertura (<i>Open</i>)</li>
#   <li>Preço de Fechamento (<i>Close</i>)</li>
#   <li>Máxima (<i>High</i>)</li>
#   <li>Mínima (<i>Low</i>)</li>
#   <li>Volume</li>
#   <li>Amplitude Diária (<i>Daily Range</i>)</li>
#   <li>Corpo Real (<i>Real Body</i>)</li>
#   <li>Sombras Superior e Inferior (<i>Upper / Lower Shadow</i>)</li>
#   <li>Log-Retorno (<i>t</i>, <i>t−1</i>)</li>
#   <li>Janelas Deslizantes — 14, 16, 30 e 60 períodos</li>
# </ul>
#
# <b>II) Indicadores Técnicos</b>
# <ul>
#   <li>Média Móvel Simples (SMA — 7 e 21)</li>
#   <li>Média Móvel Exponencial (EMA — 12 e 26)</li>
#   <li>RSI (7 e 14)</li>
#   <li>MACD (12, 26 e Sinal)</li>
#   <li>Bandas de Bollinger (21 períodos)</li>
#   <li>ATR (7 e 14)</li>
#   <li>High–Low Spread</li>
#   <li>Squeeze Momentum (<i>SQZ</i>)</li>
# </ul>
#
# </div>

# %%
DATA_INICIAL = '2019-04-09'
DATA_FIM = '2025-10-01'

# %%
ticker = "ITUB4.SA"
itau = yf.download(ticker, start=DATA_INICIAL, end=DATA_FIM)
print(itau.head())
if isinstance(itau.columns, pd.MultiIndex):
    itau.columns = itau.columns.get_level_values(0)
itau.columns
# Out:
# C:\Users\alexi\AppData\Local\Temp\ipykernel_2576\2117986326.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   itau = yf.download(ticker, start=DATA_INICIAL, end=DATA_FIM)
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open    Volume
# Ticker       ITUB4.SA   ITUB4.SA   ITUB4.SA   ITUB4.SA  ITUB4.SA
# Date
# 2019-04-09  20.461088  20.503028  20.137544  20.491046  15165318
# 2019-04-10  20.425129  20.634832  20.257366  20.610867  29815914
# 2019-04-11  19.951803  20.395177  19.837964  20.263362  13699556
# 2019-04-12  19.742102  20.263364  19.562356  19.772059  33375347
# 2019-04-15  19.730120  19.969781  19.556366  19.915857  18725884
# Index(['Close', 'High', 'Low', 'Open', 'Volume'], dtype='object', name='Price')

# %% [markdown]
# <div style="
#     font-size: 0.85em;
#     color: #c9c9c9;
#     border-left: 3px solid #555;
#     padding-left: 12px;
#     margin-top: 8px;
# ">
#
# <b>Amplitude Diária (<i>Daily Range</i>)</b><br>
# Calculada pela diferença aritmética entre a máxima e a mínima do dia (<i>H<sub>t</sub> − L<sub>t</sub></i>).
# Captura a <b>volatilidade intradiária absoluta</b>, servindo como proxy para a <b>incerteza</b> e a <b>agressividade</b> dos participantes do mercado durante o pregão, independentemente da direção do fechamento.
#
# </div>
#
# <div style="
#     font-size: 0.85em;
#     color: #c9c9c9;
#     border-left: 3px solid #555;
#     padding-left: 12px;
#     margin-top: 8px;
# ">
#
# <b>Corpo Real (<i>Real Body</i>)</b><br>
# Representa o deslocamento líquido do preço, calculado como (<i>C<sub>t</sub> − O<sub>t</sub></i>).
# Quantifica matematicamente a <b>força direcional</b> e a <b>convicção</b> do movimento: valores positivos indicam domínio comprador, enquanto valores negativos indicam domínio vendedor.
# Para o modelo, é essencial para diferenciar dias de <b>alta convicção</b> de períodos de <b>indecisão</b> (ex.: <i>Doji</i>).
#
# </div>
#
# <div style="
#     font-size: 0.85em;
#     color: #c9c9c9;
#     border-left: 3px solid #555;
#     padding-left: 12px;
#     margin-top: 8px;
# ">
#
# <b>Sombras Superior e Inferior (<i>Upper & Lower Shadows</i>)</b><br>
# Quantificam a <b>rejeição de preços</b> em extremos intradiários.
# A <b>Sombra Superior</b> (<i>H<sub>t</sub> − max(O<sub>t</sub>, C<sub>t</sub>)</i>) indica pressão vendedora em níveis elevados, enquanto a <b>Sombra Inferior</b> (<i>min(O<sub>t</sub>, C<sub>t</sub>) − L<sub>t</sub></i>) reflete defesa compradora em níveis baixos.
# São vitais para detectar <b>exaustão de tendência</b> e <b>armadilhas de liquidez</b>.
#
# </div>

# %%
itau['Daily_Range'] = itau['High'] - itau['Low']
itau['Real_Body'] = itau['Close'] - itau['Open']
itau['Upper_Shadow'] = itau['High'] - itau[['Open', 'Close']].max(axis=1)
itau['Lower_Shadow'] = itau[['Open', 'Close']].min(axis=1) - itau['Low']
print(itau.head())

itau.columns
# Out:
# Price           Close       High        Low       Open    Volume  Daily_Range  \
# Date
# 2019-04-09  20.461088  20.503028  20.137544  20.491046  15165318     0.365483
# 2019-04-10  20.425129  20.634832  20.257366  20.610867  29815914     0.377466
# 2019-04-11  19.951803  20.395177  19.837964  20.263362  13699556     0.557212
# 2019-04-12  19.742102  20.263364  19.562356  19.772059  33375347     0.701009
# 2019-04-15  19.730120  19.969781  19.556366  19.915857  18725884     0.413415
#
# Price       Real_Body  Upper_Shadow  Lower_Shadow
# Date
# 2019-04-09  -0.029957      0.011982      0.323544
# 2019-04-10  -0.185738      0.023965      0.167763
# 2019-04-11  -0.311559      0.131814      0.113839
# 2019-04-12  -0.029957      0.491305      0.179746
# 2019-04-15  -0.185737      0.053924      0.173754
# Index(['Close', 'High', 'Low', 'Open', 'Volume', 'Daily_Range', 'Real_Body',
#        'Upper_Shadow', 'Lower_Shadow'],
#       dtype='object', name='Price')

# %% [markdown]
# <div style="
#     font-size: 0.85em;
#     color: #c9c9c9;
#     border-left: 3px solid #555;
#     padding-left: 12px;
#     margin-top: 8px;
# ">
#
# <b>Log-Retorno (<i>Log Returns</i>)</b><br>
# Diferença entre o logaritmo natural do preço atual e o anterior (<i>ln(P<sub>t</sub> / P<sub>t−1</sub>)</i>).
# É preferível ao retorno simples por favorecer a <b>estacionariedade</b> da série e a <b>simetria estatística</b> — movimentos de alta e baixa de mesma intensidade possuem magnitudes numéricas equivalentes.
# Essa propriedade facilita a <b>convergência</b> e a estabilidade de algoritmos baseados em <b>gradient boosting</b>.
#
# </div>

# %%
itau['log_retorno'] = np.log(itau['Close']/itau['Close'].shift(1))
itau['Log_Retorno_t-1'] = itau['log_retorno'].shift(1)
print(itau['log_retorno'].head())
itau.columns
# Out:
# Date
# 2019-04-09         NaN
# 2019-04-10   -0.001759
# 2019-04-11   -0.023446
# 2019-04-12   -0.010566
# 2019-04-15   -0.000607
# Name: log_retorno, dtype: float64
# Index(['Close', 'High', 'Low', 'Open', 'Volume', 'Daily_Range', 'Real_Body',
#        'Upper_Shadow', 'Lower_Shadow', 'log_retorno', 'Log_Retorno_t-1'],
#       dtype='object', name='Price')

# %% [markdown]
# <div style="
#     font-size: 0.85em;
#     color: #c9c9c9;
#     border-left: 3px solid #555;
#     padding-left: 12px;
#     margin-top: 8px;
# ">
#
# <b>Janelas Deslizantes — Médias e Volatilidade (Rolling Statistics)</b><br>
# Estatísticas aplicadas sobre janelas de <b>14, 30 e 60 períodos</b>.
# A <b>Média Móvel</b> captura a tendência central de curto e médio prazo, enquanto a <b>Volatilidade</b> (desvio padrão dos <i>log-retornos</i>) quantifica o risco histórico recente.
# Essa dualidade permite ao modelo contextualizar o preço atual dentro de diferentes <b>regimes de mercado</b> — <i>calmo/direcional</i> versus <i>volátil/errático</i>.
#
# </div>

# %%
janelas = [14, 30, 60]

for n in janelas:
    itau[f'JanelaMedia{n}'] = itau['Close'].rolling(window=n).mean()

    itau[f'Volatilidade{n}'] = itau['log_retorno'].rolling(window=n).std() 

itau.columns
# Out:
# Index(['Close', 'High', 'Low', 'Open', 'Volume', 'Daily_Range', 'Real_Body',
#        'Upper_Shadow', 'Lower_Shadow', 'log_retorno', 'Log_Retorno_t-1',
#        'JanelaMedia14', 'Volatilidade14', 'JanelaMedia30', 'Volatilidade30',
#        'JanelaMedia60', 'Volatilidade60'],
#       dtype='object', name='Price')

# %% [markdown]
# ## II. Indicadores Técnicos e Momentum
#
# <div style="
#     font-size: 0.85em;
#     color: #c9c9c9;
#     border-left: 3px solid #555;
#     padding-left: 12px;
#     margin-top: 10px;
# ">
#
# <b>Média Móvel Simples (SMA — 7 e 21 períodos)</b><br>
# Filtro linear que calcula a média aritmética dos preços de fechamento (<i>AdjClose</i>).
# Atua como um <b>suavizador de ruído de alta frequência</b>, permitindo ao modelo identificar a tendência prevalente.
# A janela de <b>7 períodos</b> captura o fluxo imediato (semanal), enquanto a de <b>21 períodos</b> representa o consenso mensal de valor.
#
# </div>
#
# <div style="
#     font-size: 0.85em;
#     color: #c9c9c9;
#     border-left: 3px solid #555;
#     padding-left: 12px;
#     margin-top: 8px;
# ">
#
# <b>Média Móvel Exponencial (EMA — 12 e 26 períodos)</b><br>
# Diferentemente da SMA, aplica um fator de ponderação recursivo que atribui maior peso aos dados mais recentes.
# É matematicamente mais <b>reativa</b> (<i>α = 2/(N + 1)</i>), permitindo detectar <b>reversões de tendência</b> com menor atraso (<i>lag</i>).
# Serve como base para indicadores derivados, sendo fundamental na construção do <b>MACD</b>.
#
# </div>

# %%
itau['SMA_7'] = itau['Close'].rolling(window=7).mean()
itau['SMA_21'] = itau['Close'].rolling(window=21).mean()

itau['EMA_12'] =itau['Close'].ewm(span=12, adjust=False).mean()
itau['EMA_26'] =itau['Close'].ewm(span=26, adjust=False).mean()

itau.columns
# Out:
# Index(['Close', 'High', 'Low', 'Open', 'Volume', 'Daily_Range', 'Real_Body',
#        'Upper_Shadow', 'Lower_Shadow', 'log_retorno', 'Log_Retorno_t-1',
#        'JanelaMedia14', 'Volatilidade14', 'JanelaMedia30', 'Volatilidade30',
#        'JanelaMedia60', 'Volatilidade60', 'SMA_7', 'SMA_21', 'EMA_12',
#        'EMA_26'],
#       dtype='object', name='Price')

# %% [markdown]
# <div style="
#     font-size: 0.85em;
#     color: #c9c9c9;
#     border-left: 3px solid #555;
#     padding-left: 12px;
#     margin-top: 8px;
# ">
#
# <b>MACD (Moving Average Convergence Divergence)</b><br>
# Oscilador calculado pela diferença entre a <b>EMA rápida (12)</b> e a <b>EMA lenta (26)</b>.
# Mede a <b>velocidade</b> e a <b>aceleração</b> da tendência.
# O modelo utiliza tanto a <b>linha MACD</b> quanto o seu <b>Sinal</b> (suavização de 9 períodos) para identificar <b>divergências</b> e o <b>momentum</b> do movimento atual em relação ao histórico.
#
# </div>

# %%
itau['MACD_Line'] = itau['EMA_12'] - itau['EMA_26']
itau['MACD_Signal'] = itau['MACD_Line'].ewm(span=9, adjust=False).mean()

itau.columns
# Out:
# Index(['Close', 'High', 'Low', 'Open', 'Volume', 'Daily_Range', 'Real_Body',
#        'Upper_Shadow', 'Lower_Shadow', 'log_retorno', 'Log_Retorno_t-1',
#        'JanelaMedia14', 'Volatilidade14', 'JanelaMedia30', 'Volatilidade30',
#        'JanelaMedia60', 'Volatilidade60', 'SMA_7', 'SMA_21', 'EMA_12',
#        'EMA_26', 'MACD_Line', 'MACD_Signal'],
#       dtype='object', name='Price')

# %% [markdown]
# <div style="
#     font-size: 0.85em;
#     color: #c9c9c9;
#     border-left: 3px solid #555;
#     padding-left: 12px;
#     margin-top: 8px;
# ">
#
# <b>RSI (Relative Strength Index — 7 e 14 períodos)</b><br>
# Indicador de <b>momentum</b> normalizado entre 0 e 100, calculado pela razão suavizada (método de Wilder) entre ganhos e perdas médios.
# Identifica condições de <b>sobrecompra</b> (&gt; 70) e <b>sobrevenda</b> (&lt; 30), além da velocidade da mudança dos preços, sinalizando potenciais pontos de <b>reversão à média</b>.
#
# </div>

# %%
itau['Delta'] = itau['Close'].diff()
itau['Gain'] = itau['Delta'].clip(lower=0)
itau['Loss'] = itau['Delta'].clip(upper=0).abs()

periodos_rsi = [7, 14]

for n in periodos_rsi:
    avg_gain = itau['Gain'].ewm(alpha=1/n, min_periods=n, adjust=False).mean()
    avg_loss = itau['Loss'].ewm(alpha=1/n, min_periods=n, adjust=False).mean()
    
    rs = avg_gain / avg_loss
    
    itau[f'RSI_{n}'] = 100 - (100 / (1 + rs))
itau.drop(columns=['Delta', 'Gain', 'Loss'], inplace=True)

print(itau[['RSI_7', 'RSI_14']].tail())
itau.columns
# Out:
# Price           RSI_7     RSI_14
# Date
# 2025-09-24  59.048446  59.213273
# 2025-09-25  52.041768  55.648747
# 2025-09-26  55.792719  57.343663
# 2025-09-29  60.017041  59.283880
# 2025-09-30  63.359209  60.852816
# Index(['Close', 'High', 'Low', 'Open', 'Volume', 'Daily_Range', 'Real_Body',
#        'Upper_Shadow', 'Lower_Shadow', 'log_retorno', 'Log_Retorno_t-1',
#        'JanelaMedia14', 'Volatilidade14', 'JanelaMedia30', 'Volatilidade30',
#        'JanelaMedia60', 'Volatilidade60', 'SMA_7', 'SMA_21', 'EMA_12',
#        'EMA_26', 'MACD_Line', 'MACD_Signal', 'RSI_7', 'RSI_14'],
#       dtype='object', name='Price')

# %% [markdown]
# <div style="
#     font-size: 0.85em;
#     color: #c9c9c9;
#     border-left: 3px solid #555;
#     padding-left: 12px;
#     margin-top: 8px;
# ">
#
# <b>Bandas de Bollinger (21 períodos, 2 desvios)</b><br>
# Envelope de volatilidade composto por uma média central e duas bandas externas (<i>μ ± 2σ</i>).
# Contextualizam o preço em termos estatísticos: toques nas bandas indicam desvios extremos da normalidade.
# Para o algoritmo, funcionam como medidas dinâmicas de <b>suporte</b>, <b>resistência</b> e <b>expansão de volatilidade</b>.
#
# </div>

# %%
itau['BBmean'] = itau['Close'].rolling(window=21).mean()
itau['BBstd'] = itau['Close'].rolling(window=21).std()

itau['BBupper'] = itau['BBmean'] + (2* itau['BBstd'])
itau['BBLower'] = itau['BBmean'] - (2* itau['BBstd'])

itau.columns
# Out:
# Index(['Close', 'High', 'Low', 'Open', 'Volume', 'Daily_Range', 'Real_Body',
#        'Upper_Shadow', 'Lower_Shadow', 'log_retorno', 'Log_Retorno_t-1',
#        'JanelaMedia14', 'Volatilidade14', 'JanelaMedia30', 'Volatilidade30',
#        'JanelaMedia60', 'Volatilidade60', 'SMA_7', 'SMA_21', 'EMA_12',
#        'EMA_26', 'MACD_Line', 'MACD_Signal', 'RSI_7', 'RSI_14', 'BBmean',
#        'BBstd', 'BBupper', 'BBLower'],
#       dtype='object', name='Price')

# %% [markdown]
# <div style="
#     font-size: 0.85em;
#     color: #c9c9c9;
#     border-left: 3px solid #555;
#     padding-left: 12px;
#     margin-top: 8px;
# ">
#
# <b>ATR (Average True Range)</b><br>
# Mede a volatilidade absoluta considerando a amplitude do dia e os gaps de abertura em relação ao fechamento anterior.
# Essencial para modelagem de risco e definição de stops em pontos reais.
#
# </div>

# %%
itau['Prev_Close'] = itau['Close'].shift(1)

itau['Range_1'] = itau['High'] - itau['Low']
itau['Range_2'] = (itau['High'] - itau['Prev_Close']).abs()
itau['Range_3'] = (itau['Low'] - itau['Prev_Close']).abs()

itau['TR'] = itau[['Range_1', 'Range_2', 'Range_3']].max(axis=1)
itau['ATR_7'] = itau['TR'].rolling(window=7).mean()
itau['ATR_14'] = itau['TR'].rolling(window=14).mean()

itau.drop(columns=['Prev_Close', 'Range_1', 'Range_2', 'Range_3'], inplace=True)
print(itau[['TR', 'ATR_7', 'ATR_14']].tail())
itau.columns
# Out:
# Price             TR     ATR_7    ATR_14
# Date
# 2025-09-24  0.394193  0.580157  0.616827
# 2025-09-25  0.504200  0.576229  0.595218
# 2025-09-26  0.348355  0.500272  0.578193
# 2025-09-29  0.632536  0.539559  0.586050
# 2025-09-30  0.715047  0.569680  0.601111
# Index(['Close', 'High', 'Low', 'Open', 'Volume', 'Daily_Range', 'Real_Body',
#        'Upper_Shadow', 'Lower_Shadow', 'log_retorno', 'Log_Retorno_t-1',
#        'JanelaMedia14', 'Volatilidade14', 'JanelaMedia30', 'Volatilidade30',
#        'JanelaMedia60', 'Volatilidade60', 'SMA_7', 'SMA_21', 'EMA_12',
#        'EMA_26', 'MACD_Line', 'MACD_Signal', 'RSI_7', 'RSI_14', 'BBmean',
#        'BBstd', 'BBupper', 'BBLower', 'TR', 'ATR_7', 'ATR_14'],
#       dtype='object', name='Price')

# %% [markdown]
# <div style="
#     font-size: 0.85em;
#     color: #c9c9c9;
#     border-left: 3px solid #555;
#     padding-left: 12px;
#     margin-top: 8px;
# ">
#
# <b>SQZ (Squeeze Momentum)</b><br>
# Indicador híbrido que identifica períodos de compressão de volatilidade.
# Matematicamente, ocorre quando as <b>Bandas de Bollinger</b> estreitam-se em relação aos <b>Canais de Keltner</b> (baseados em ATR).
# Sinaliza regimes de <b>acumulação silenciosa</b> que estatisticamente precedem movimentos explosivos de preço.
#
# </div>

# %%
itau['KC_Upper'] = itau['SMA_21'] + (1.5 * itau['ATR_14'])
itau['KC_Lower'] = itau['SMA_21'] - (1.5 * itau['ATR_14'])

condicao_teto = itau['BBupper'] < itau['KC_Upper']
condicao_chao = itau['BBLower'] > itau['KC_Lower']

itau['SQZ_On'] = (condicao_teto & condicao_chao).astype(int)
itau.drop(columns=['KC_Upper', 'KC_Lower'], inplace=True)

print(itau['SQZ_On'].value_counts())
itau.columns
# Out:
# SQZ_On
# 0    1303
# 1     311
# Name: count, dtype: int64
# Index(['Close', 'High', 'Low', 'Open', 'Volume', 'Daily_Range', 'Real_Body',
#        'Upper_Shadow', 'Lower_Shadow', 'log_retorno', 'Log_Retorno_t-1',
#        'JanelaMedia14', 'Volatilidade14', 'JanelaMedia30', 'Volatilidade30',
#        'JanelaMedia60', 'Volatilidade60', 'SMA_7', 'SMA_21', 'EMA_12',
#        'EMA_26', 'MACD_Line', 'MACD_Signal', 'RSI_7', 'RSI_14', 'BBmean',
#        'BBstd', 'BBupper', 'BBLower', 'TR', 'ATR_7', 'ATR_14', 'SQZ_On'],
#       dtype='object', name='Price')

# %% [markdown]
# <div style="
#     font-size: 0.85em;
#     color: #c9c9c9;
#     border-left: 3px solid #555;
#     padding-left: 12px;
#     margin-top: 8px;
# ">
#
# <b>KDJ (Oscilador Estocástico Derivado)</b><br>
# Refinamento do oscilador estocástico clássico, composto pelas linhas <b>K</b> (rápida), <b>D</b> (lenta) e <b>J</b> (divergência).
# O KDJ localiza o fechamento atual dentro do intervalo Máxima–Mínima recente.
# A linha <b>J</b>, mais sensível, permite antecipar pontos de virada de curto prazo com maior precisão que o estocástico tradicional.
#
# </div>

# %%
itau['Low_14'] = itau['Low'].rolling(window=14).min()
itau['High_14'] = itau['High'].rolling(window=14).max()

itau['RSV'] = 100 * ((itau['Close'] - itau['Low_14']) / (itau['High_14'] - itau['Low_14']))

itau['K'] = itau['RSV'].ewm(com=2, adjust=False).mean()
itau['D'] = itau['K'].ewm(com=2, adjust=False).mean()
itau['J'] = (3 * itau['K']) - (2 * itau['D'])

itau.drop(columns=['Low_14', 'High_14', 'RSV'], inplace=True)

# Conferência final da Parte II
print("Colunas Finais da Parte II:")
print(itau.columns[-3:])
# Out:
# Colunas Finais da Parte II:
# Index(['K', 'D', 'J'], dtype='object', name='Price')

# %% [markdown]
# Dado que usaremos o XGboost, devemos aplicar um alvo, nesse sentido, criamos 2: Um alvo de retorno(Retorno 5 dias) e um alvo binário (Retorno positivo ou não em 5 dias)

# %%
import numpy as np
import pandas as pd

itau_semanal = itau[itau.index.dayofweek == 4].copy()

itau_semanal.dropna(inplace=True)

itau_semanal['AlvoRetorno'] = itau_semanal['Close'].shift(-1) / itau_semanal['Close'] - 1
itau_semanal['Alvo'] = np.where(itau_semanal['AlvoRetorno'] > 0, 1, 0)

itau_semanal.dropna(subset=['Alvo', 'AlvoRetorno'], inplace=True)
itau_semanal['Alvo'] = itau_semanal['Alvo'].astype(int)

itau_semanal.index.to_series().to_csv('./dados/BaseA.csv', index=False, header=['Data'])

# %% [markdown]
# Seja o nosso rebalanceamento somente nas sextas feiras em um intervalo semanal, então filtramos somente os dados onde a data era sexta feira, a fim de evitar o ruido dos outros dias que só serviriam para prever 5D+, algo nao útil quando focamos na sexta.

# %% [markdown]
# Tratamento de feature
#
# Coeficiente de Correlação de Pearson

# %%
featuresTest = [c for c in itau_semanal.columns if c not in ['Alvo', 'AlvoRetorno', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']]
X = itau_semanal[featuresTest]
y = itau_semanal['Alvo']

corr_matrix = X.corr().abs() #pearsson 

upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))

drop = [column for column in upper.columns if any(upper[column] > 0.95)]

print(f"Features detectadas com alta correlação (> 0.95): {len(drop)}")
print(drop)

itau_final = X.drop(columns=drop)
print("Shape final das features após Pearson:", itau_final.shape)
# Out:
# Features detectadas com alta correlação (> 0.95): 12
# ['JanelaMedia30', 'JanelaMedia60', 'SMA_7', 'SMA_21', 'EMA_12', 'EMA_26', 'MACD_Signal', 'BBmean', 'BBupper', 'BBLower', 'TR', 'D']
# Shape final das features após Pearson: (307, 19)

# %%
itau_final.columns
# Out:
# Index(['Daily_Range', 'Real_Body', 'Upper_Shadow', 'Lower_Shadow',
#        'log_retorno', 'Log_Retorno_t-1', 'JanelaMedia14', 'Volatilidade14',
#        'Volatilidade30', 'Volatilidade60', 'MACD_Line', 'RSI_7', 'RSI_14',
#        'BBstd', 'ATR_7', 'ATR_14', 'SQZ_On', 'K', 'J'],
#       dtype='object', name='Price')

# %%
mi_scores = mutual_info_classif(itau_final, y, random_state=42)
mi_series = pd.Series(mi_scores, index=itau_final.columns).sort_values(ascending=False)

scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(itau_final)
chi2_scores, p_values = chi2(X_scaled, y)
chi2_series = pd.Series(chi2_scores, index=itau_final.columns).sort_values(ascending=False)

print("TOP 10 Features por Informação Mútua")
print(mi_series.head(10))

print("\nTOP 10 Features por Qui-Quadrado")
print(chi2_series.head(10))
# Out:
# TOP 10 Features por Informação Mútua
# Price
# ATR_7              0.054490
# Daily_Range        0.052918
# log_retorno        0.049138
# SQZ_On             0.043991
# RSI_7              0.036605
# Log_Retorno_t-1    0.024079
# K                  0.022948
# RSI_14             0.022775
# Volatilidade14     0.014256
# Upper_Shadow       0.013956
# dtype: float64
#
# TOP 10 Features por Qui-Quadrado
# Price
# SQZ_On            0.254139
# RSI_7             0.242000
# J                 0.231685
# K                 0.168918
# Daily_Range       0.158477
# RSI_14            0.108208
# Volatilidade14    0.095078
# ATR_14            0.089462
# ATR_7             0.079883
# BBstd             0.043395
# dtype: float64

# %%
lim = 0.01 

featSelect = chi2_series[chi2_series > lim].index.tolist()
featDrop = chi2_series[chi2_series <= lim].index.tolist()

itau_otimizado = itau_final[featSelect].copy()

print(f"Critério de Corte: Score > {lim}")
print(f"Total Original: {len(chi2_series)} variáveis")
print(f"Total Selecionado: {len(featSelect)} variáveis")
print("-" * 30)

print("\n VARIÁVEIS DESCARTADAS (Ruído):")
print(featDrop)

print("\n VARIÁVEIS MANTIDAS (Input do Modelo):")
print(itau_otimizado.columns.tolist())

print(itau_otimizado.describe().loc[['count', 'mean']])
# Out:
# Critério de Corte: Score > 0.01
# Total Original: 19 variáveis
# Total Selecionado: 16 variáveis
# ------------------------------
#
#  VARIÁVEIS DESCARTADAS (Ruído):
# ['Volatilidade60', 'log_retorno', 'MACD_Line']
#
#  VARIÁVEIS MANTIDAS (Input do Modelo):
# ['SQZ_On', 'RSI_7', 'J', 'K', 'Daily_Range', 'RSI_14', 'Volatilidade14', 'ATR_14', 'ATR_7', 'BBstd', 'Volatilidade30', 'Log_Retorno_t-1', 'JanelaMedia14', 'Upper_Shadow', 'Lower_Shadow', 'Real_Body']
# Price     SQZ_On       RSI_7          J           K  Daily_Range      RSI_14  \
# count  307.00000  307.000000  307.00000  307.000000   307.000000  307.000000
# mean     0.19544   51.855226   51.59337   52.019462     0.480941   52.216382
#
# Price  Volatilidade14      ATR_14       ATR_7       BBstd  Volatilidade30  \
# count      307.000000  307.000000  307.000000  307.000000      307.000000
# mean         0.016948    0.524921    0.526198    0.602301        0.017211
#
# Price  Log_Retorno_t-1  JanelaMedia14  Upper_Shadow  Lower_Shadow   Real_Body
# count       307.000000     307.000000    307.000000    307.000000  307.000000
# mean          0.000521      20.971095      0.131431      0.133166   -0.020945

# %%
itau_otimizado.columns
# Out:
# Index(['SQZ_On', 'RSI_7', 'J', 'K', 'Daily_Range', 'RSI_14', 'Volatilidade14',
#        'ATR_14', 'ATR_7', 'BBstd', 'Volatilidade30', 'Log_Retorno_t-1',
#        'JanelaMedia14', 'Upper_Shadow', 'Lower_Shadow', 'Real_Body'],
#       dtype='object', name='Price')

# %% [markdown]
# Filtramos as variáveis com alta correlação via Pearson e validamos sua importância através dos testes de Qui-Quadrado e Informação Mútua. Observou-se que as métricas estão consistentemente distantes de zero (o que indicaria independência ou ruído), confirmando que estas variáveis possuem sinal suficiente para contribuir com o desempenho do modelo.

# %%
print(itau_otimizado.isna().any())
# Out:
# Price
# SQZ_On             False
# RSI_7              False
# J                  False
# K                  False
# Daily_Range        False
# RSI_14             False
# Volatilidade14     False
# ATR_14             False
# ATR_7              False
# BBstd              False
# Volatilidade30     False
# Log_Retorno_t-1    False
# JanelaMedia14      False
# Upper_Shadow       False
# Lower_Shadow       False
# Real_Body          False
# dtype: bool

# %%
itau_otimizado.to_csv('./dados/teste.csv')

# %% [markdown]
# Automatizando para todas as ações

# %%
try:
    interseccao = pd.read_csv('./dados/Interseccao.csv')
    datasOfc = pd.to_datetime(interseccao['Data']).unique()
except:
    datasOfc = []

DATA_INICIAL = '2019-04-09' 
DATA_FIM = '2025-10-01'

ativos = pd.read_csv('ibovespa.csv', sep=';')

ativos.columns = [col.strip().lower() for col in ativos.columns]
tickers = ativos['ticker']

features_A = {}

print("Iniciando processamento")

for ticker in tickers:

    df = yf.download(ticker, start=DATA_INICIAL, end=DATA_FIM, progress=False, auto_adjust=True)
        
    if isinstance(df.columns, pd.MultiIndex):
        df.columns = df.columns.get_level_values(0)
    
    if df.empty:
        continue

    df['Daily_Range'] = df['High'] - df['Low']
    df['Real_Body'] = df['Close'] - df['Open']
    df['Upper_Shadow'] = df['High'] - df[['Open', 'Close']].max(axis=1)
    df['Lower_Shadow'] = df[['Open', 'Close']].min(axis=1) - df['Low']
    
    df['log_retorno'] = np.log(df['Close']/df['Close'].shift(1))
    df['Log_Retorno_t-1'] = df['log_retorno'].shift(1)

    janelas = [14, 30, 60]
    for n in janelas:
        df[f'JanelaMedia{n}'] = df['Close'].rolling(window=n).mean()
        df[f'Volatilidade{n}'] = df['log_retorno'].rolling(window=n).std() 

    df['SMA_7']  =  df['Close'].rolling(window=7).mean()
    df['SMA_21'] = df['Close'].rolling(window=21).mean()
    df['EMA_12'] = df['Close'].ewm(span=12, adjust=False).mean()
    df['EMA_26'] = df['Close'].ewm(span=26, adjust=False).mean()

    df['MACD_Line'] = df['EMA_12'] - df['EMA_26']
    df['MACD_Signal'] = df['MACD_Line'].ewm(span=9, adjust=False).mean()

    df['Delta'] = df['Close'].diff()
    df['Gain'] = df['Delta'].clip(lower=0)
    df['Loss'] = df['Delta'].clip(upper=0).abs()

    periodos_rsi = [7, 14]
    for n in periodos_rsi:
        avg_gain = df['Gain'].ewm(alpha=1/n, min_periods=n, adjust=False).mean()
        avg_loss = df['Loss'].ewm(alpha=1/n, min_periods=n, adjust=False).mean()
        rs = avg_gain / avg_loss
        df[f'RSI_{n}'] = 100 - (100 / (1 + rs))
    df.drop(columns=['Delta', 'Gain', 'Loss'], inplace=True)

    df['BBmean'] = df['Close'].rolling(window=21).mean()
    df['BBstd'] = df['Close'].rolling(window=21).std()
    df['BBupper'] = df['BBmean'] + (2* df['BBstd'])
    df['BBLower'] = df['BBmean'] - (2* df['BBstd'])

    df['Prev_Close'] = df['Close'].shift(1)
    df['Range_1'] = df['High'] - df['Low']
    df['Range_2'] = (df['High'] - df['Prev_Close']).abs()
    df['Range_3'] = (df['Low'] - df['Prev_Close']).abs()
    df['TR'] = df[['Range_1', 'Range_2', 'Range_3']].max(axis=1)
    df['ATR_7'] = df['TR'].rolling(window=7).mean()
    df['ATR_14'] = df['TR'].rolling(window=14).mean()
    df.drop(columns=['Prev_Close', 'Range_1', 'Range_2', 'Range_3'], inplace=True)
    
    df['KC_Upper'] = df['SMA_21'] + (1.5 * df['ATR_14'])
    df['KC_Lower'] = df['SMA_21'] - (1.5 * df['ATR_14'])
    condicao_teto = df['BBupper'] < df['KC_Upper']
    condicao_chao = df['BBLower'] > df['KC_Lower']
    df['SQZ_On'] = (condicao_teto & condicao_chao).astype(int)
    df.drop(columns=['KC_Upper', 'KC_Lower'], inplace=True)

    df['Low_14'] = df['Low'].rolling(window=14).min()
    df['High_14'] = df['High'].rolling(window=14).max()
    df['RSV'] = 100 * ((df['Close'] - df['Low_14']) / (df['High_14'] - df['Low_14']))
    df['K'] = df['RSV'].ewm(com=2, adjust=False).mean()
    df['D'] = df['K'].ewm(com=2, adjust=False).mean()
    df['J'] = (3 * df['K']) - (2 * df['D'])
    df.drop(columns=['Low_14', 'High_14', 'RSV'], inplace=True)

    df = df[df.index.dayofweek == 4].copy()

    df.dropna(inplace=True)

    df['AlvoRetorno'] = df['Close'].shift(-1) / df['Close'] - 1
    df['Alvo'] = np.where(df['AlvoRetorno'] > 0, 1, 0)
    
    df.dropna(subset=['Alvo', 'AlvoRetorno'], inplace=True)
    df['Alvo'] = df['Alvo'].astype(int)

    if len(datasOfc) > 0:
        df.index = pd.to_datetime(df.index)
        df = df[df.index.isin(datasOfc)].copy()

    featuresTest = [c for c in df.columns if c not in ['Alvo', 'AlvoRetorno', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']]
    X = df[featuresTest]
    y = df['Alvo']

    if len(X) < 10:
        print(f"Aviso: {ticker} ficou com dados insuficientes. Pulando.")
        continue

    corr_matrix = X.corr().abs() 
    upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
    drop = [column for column in upper.columns if any(upper[column] > 0.95)]
    var = X.drop(columns=drop)

    mi_scores = mutual_info_classif(var, y, random_state=42)
    mi_series = pd.Series(mi_scores, index=var.columns).sort_values(ascending=False)

    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(var)
    chi2_scores, p_values = chi2(X_scaled, y)
    chi2_series = pd.Series(chi2_scores, index=var.columns).sort_values(ascending=False)

    lim = 0.01 
    featSelect = chi2_series[chi2_series > lim].index.tolist()
    
    varFinal = var[featSelect].copy()
    
    varFinal['Alvo'] = df['Alvo']
    varFinal['AlvoRetorno'] = df['AlvoRetorno']
    
    features_A[ticker] = varFinal

    print(f'{ticker} Processado')

print("Processo de features concluído")
# Out:
# Iniciando processamento
# PETR4.SA Processado
# ITUB4.SA Processado
# VALE3.SA Processado
# BPAC11.SA Processado
# ABEV3.SA Processado
# WEGE3.SA Processado
# BBDC3.SA Processado
# ITSA4.SA Processado
# BBAS3.SA Processado
# SANB11.SA Processado
# VIVT3.SA Processado
# SBSP3.SA Processado
# BBSE3.SA Processado
# B3SA3.SA Processado
# SUZB3.SA Processado
# CPFE3.SA Processado
# TIMS3.SA Processado
# EQTL3.SA Processado
# RENT3.SA Processado
# RADL3.SA Processado
# NEOE3.SA Processado
# ENEV3.SA Processado
# GGBR3.SA Processado
# EGIE3.SA Processado
# CMIG4.SA Processado
# PRIO3.SA Processado
# VBBR3.SA Processado
# RAIL3.SA Processado
# TOTS3.SA Processado
# ENGI11.SA Processado
# KLBN11.SA Processado
# UGPA3.SA Processado
# CSAN3.SA Processado
# CSMG3.SA Processado
# GOAU4.SA Processado
# HYPE3.SA Processado
# ALOS3.SA Processado
# MULT3.SA Processado
# TAEE11.SA Processado
# LREN3.SA Processado
# REDE3.SA Processado
# CSNA3.SA Processado
# CYRE3.SA Processado
# ALUP11.SA Processado
# FLRY3.SA Processado
# USIM5.SA Processado
# BRAP4.SA Processado
# HAPV3.SA Processado
# SLCE3.SA Processado
# MGLU3.SA Processado
# COGN3.SA Processado
# BRKM5.SA Processado
# BEEF3.SA Processado
# MRVE3.SA Processado
# DXCO3.SA Processado
# IRBR3.SA Processado
# EZTC3.SA Processado
# YDUQ3.SA Processado
# AZUL4.SA Processado
# Processo de features concluído

# %% [markdown]
# Teste de datas iguais em ambos os modelos

# %%
print(features_A['PETR4.SA'].tail(-10))
# Out:
# Price       SQZ_On        TR  Lower_Shadow  Daily_Range  Upper_Shadow  \
# Date
# 2019-12-13       0  0.311665      0.031166     0.311665      0.022667
# 2019-12-20       0  0.167165      0.068000     0.164333      0.000000
# 2019-12-27       0  0.180969      0.066068     0.180969      0.066068
# 2020-01-03       0  0.226930      0.000000     0.226930      0.103411
# 2020-01-10       0  0.089049      0.040216     0.089049      0.014363
# ...            ...       ...           ...          ...           ...
# 2025-08-22       0  0.826084      0.087271     0.649680      0.000000
# 2025-08-29       0  0.484836      0.077574     0.484836      0.242418
# 2025-09-05       0  0.872704      0.387868     0.872704      0.009697
# 2025-09-12       0  0.523624      0.019394     0.523624      0.242418
# 2025-09-19       0  0.523624      0.145450     0.523624      0.019394
#
# Price       MACD_Signal          D  Volatilidade60     ATR_7  MACD_Line  ...  \
# Date                                                                     ...
# 2019-12-13     0.092190  73.776289        0.015302  0.182546   0.103587  ...
# 2019-12-20     0.085584  66.531699        0.015703  0.193879   0.084403  ...
# 2019-12-27     0.090808  72.829154        0.015701  0.154566   0.103093  ...
# 2020-01-03     0.098029  73.897645        0.015433  0.162899   0.107432  ...
# 2020-01-10     0.102511  69.247019        0.015181  0.160862   0.093191  ...
# ...                 ...        ...             ...       ...        ...  ...
# 2025-08-22    -0.303198  19.724249        0.015315  0.520303  -0.364067  ...
# 2025-08-29    -0.207565  53.056958        0.014880  0.461648  -0.064261  ...
# 2025-09-05    -0.025016  76.814926        0.013437  0.477910   0.069237  ...
# 2025-09-12     0.073610  79.145949        0.012955  0.497303   0.153451  ...
# 2025-09-19     0.162510  79.590469        0.012393  0.430812   0.192504  ...
#
# Price       Real_Body           J  Log_Retorno_t-1  Volatilidade30          K  \
# Date
# 2019-12-13  -0.257832   75.954536         0.018576        0.016820  74.502372
# 2019-12-20  -0.096333   71.108891         0.002289        0.017377  68.057430
# 2019-12-27  -0.048833   86.730906         0.013353        0.014882  77.463071
# 2020-01-03  -0.123518   71.889952         0.017083        0.014795  73.228414
# 2020-01-10  -0.034470   49.901720        -0.003284        0.013184  62.798586
# ...               ...         ...              ...             ...        ...
# 2025-08-22   0.562410   35.616911         0.002314        0.015369  25.021803
# 2025-08-29   0.164844  107.062186         0.008768        0.015026  71.058700
# 2025-09-05  -0.475139   75.682921         0.000000        0.014837  76.437591
# 2025-09-12  -0.261812   75.980300        -0.003816        0.014842  78.090733
# 2025-09-19  -0.358779   60.218184        -0.009821        0.009461  73.133041
#
# Price       log_retorno     BBstd  Volatilidade14  Alvo  AlvoRetorno
# Date
# 2019-12-13    -0.032488  0.164105        0.014867     1     0.009340
# 2019-12-20    -0.011500  0.160956        0.016248     1     0.022551
# 2019-12-27     0.001047  0.177881        0.015214     0    -0.002294
# 2020-01-03    -0.008177  0.172034        0.016084     0    -0.005911
# 2020-01-10    -0.004286  0.130422        0.010926     0    -0.013875
# ...                 ...       ...             ...   ...          ...
# 2025-08-22     0.028358  0.955186        0.020139     1     0.020676
# 2025-08-29     0.005481  0.792242        0.010336     0    -0.016399
# 2025-09-05    -0.015248  0.627715        0.010678     1     0.019287
# 2025-09-12    -0.006712  0.658540        0.008728     0    -0.003849
# 2025-09-19    -0.011205  0.362074        0.009318     1     0.038313
#
# [285 rows x 23 columns]

# %%
print(features_A['PETR4.SA']['Alvo'])
print(features_A['PETR4.SA']['AlvoRetorno'])
# Out:
# Date
# 2019-09-27    0
# 2019-10-04    1
# 2019-10-11    1
# 2019-10-18    1
# 2019-10-25    1
#              ..
# 2025-08-22    1
# 2025-08-29    0
# 2025-09-05    1
# 2025-09-12    0
# 2025-09-19    1
# Name: Alvo, Length: 295, dtype: int64
# Date
# 2019-09-27   -0.041576
# 2019-10-04    0.028291
# 2019-10-11    0.012473
# 2019-10-18    0.059782
# 2019-10-25    0.040342
#                 ...
# 2025-08-22    0.020676
# 2025-08-29   -0.016399
# 2025-09-05    0.019287
# 2025-09-12   -0.003849
# 2025-09-19    0.038313
# Name: AlvoRetorno, Length: 295, dtype: float64

# %%
optuna.logging.set_verbosity(optuna.logging.WARNING)
warnings.filterwarnings('ignore')

modelosA = {}

for ticker, df in features_A.items():
    print(f"\n--- Treinando: {ticker} ---")
    
    features = [c for c in df.columns if c not in ['Alvo', 'AlvoRetorno']]
    X = df[features]
    y = df['Alvo']

    split = int(len(df) * 0.8)
    
    X_dev = X.iloc[:split]
    y_dev = y.iloc[:split]
    
    X_backtest = X.iloc[split:]
    y_backtest = y.iloc[split:]
    
    def objective(trial):

        cutoff = int(len(X_dev) * 0.75)
        X_train_opt, X_val_opt = X_dev.iloc[:cutoff], X_dev.iloc[cutoff:]
        y_train_opt, y_val_opt = y_dev.iloc[:cutoff], y_dev.iloc[cutoff:]
        
        params = {
            'objective': 'binary:logistic',
            'eval_metric': 'logloss',
            'n_estimators': trial.suggest_int('n_estimators', 50, 500),
            'max_depth': trial.suggest_int('max_depth', 3, 10),
            'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
            'subsample': trial.suggest_float('subsample', 0.5, 1.0),
            'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
            'reg_alpha': trial.suggest_float('reg_alpha', 0.0, 10.0),
            'reg_lambda': trial.suggest_float('reg_lambda', 0.0, 10.0),
            'gamma': trial.suggest_float('gamma', 0.0, 5.0),
            'random_state': 42,
            'n_jobs': -1
        }
        
        model = xgb.XGBClassifier(**params)
        model.fit(X_train_opt, y_train_opt)
        
        preds = model.predict(X_val_opt)
        
        score = precision_score(y_val_opt, preds, zero_division=0)
        
        return score

    study = optuna.create_study(direction='maximize')
    
    study.optimize(objective, n_trials=100) 
    
    print(f"Melhor Score: {study.best_value:.2%}")
    print(f"Melhores Parâmetros: {study.best_params}")

    best_params = study.best_params
    best_params['random_state'] = 42
    best_params['n_jobs'] = -1
    
    final_model = xgb.XGBClassifier(**best_params)
    final_model.fit(X_dev, y_dev)
    
    modelosA[ticker] = final_model
# Out:
# --- Treinando: PETR4.SA ---
# Melhor Score: 81.25%
# Melhores Parâmetros: {'n_estimators': 447, 'max_depth': 8, 'learning_rate': 0.25402352710649095, 'subsample': 0.6787141945294959, 'colsample_bytree': 0.6511537941578764, 'reg_alpha': 6.778808838054444, 'reg_lambda': 1.2927435483249374, 'gamma': 0.23797816311960562}
#
# --- Treinando: ITUB4.SA ---
# Melhor Score: 65.62%
# Melhores Parâmetros: {'n_estimators': 488, 'max_depth': 8, 'learning_rate': 0.13153567590245777, 'subsample': 0.6534322929584162, 'colsample_bytree': 0.8095519175384757, 'reg_alpha': 3.001372697107416, 'reg_lambda': 4.602572223935671, 'gamma': 0.09574514483711391}
#
# --- Treinando: VALE3.SA ---
# Melhor Score: 66.67%
# Melhores Parâmetros: {'n_estimators': 386, 'max_depth': 4, 'learning_rate': 0.253970165048202, 'subsample': 0.867184932989542, 'colsample_bytree': 0.9651102793233052, 'reg_alpha': 0.46944991837197636, 'reg_lambda': 0.6637280002181456, 'gamma': 4.136658836736668}
#
# --- Treinando: BPAC11.SA ---
# Melhor Score: 84.21%
# Melhores Parâmetros: {'n_estimators': 199, 'max_depth': 8, 'learning_rate': 0.12041691831125433, 'subsample': 0.6300558962805365, 'colsample_bytree': 0.760988616233084, 'reg_alpha': 0.01509292848170252, 'reg_lambda': 4.537789516497342, 'gamma': 1.4714777410743747}
#
# --- Treinando: ABEV3.SA ---
# Melhor Score: 48.57%
# Melhores Parâmetros: {'n_estimators': 96, 'max_depth': 6, 'learning_rate': 0.22470172023297957, 'subsample': 0.5539377048560985, 'colsample_bytree': 0.7462377648627484, 'reg_alpha': 2.675473419384221, 'reg_lambda': 2.4248054129745804, 'gamma': 3.4970137385299527}
#
# --- Treinando: WEGE3.SA ---
# Melhor Score: 54.24%
# Melhores Parâmetros: {'n_estimators': 482, 'max_depth': 10, 'learning_rate': 0.24877574180800266, 'subsample': 0.8622684342843401, 'colsample_bytree': 0.8285323785858117, 'reg_alpha': 8.821840218107784, 'reg_lambda': 4.715821182935497, 'gamma': 4.7042926253449275}
#
# --- Treinando: BBDC3.SA ---
# Melhor Score: 88.89%
# Melhores Parâmetros: {'n_estimators': 221, 'max_depth': 3, 'learning_rate': 0.03414722711140525, 'subsample': 0.6389817797830581, 'colsample_bytree': 0.6173742371523503, 'reg_alpha': 4.806412868155914, 'reg_lambda': 3.785768386514398, 'gamma': 1.851167751343815}
#
# --- Treinando: ITSA4.SA ---
# Melhor Score: 100.00%
# Melhores Parâmetros: {'n_estimators': 184, 'max_depth': 7, 'learning_rate': 0.05546490041260962, 'subsample': 0.7202002685923047, 'colsample_bytree': 0.9572429661752304, 'reg_alpha': 9.318154892974094, 'reg_lambda': 5.441545973473634, 'gamma': 0.7141982891532925}
#
# --- Treinando: BBAS3.SA ---
# Melhor Score: 87.50%
# Melhores Parâmetros: {'n_estimators': 143, 'max_depth': 8, 'learning_rate': 0.16119129430977377, 'subsample': 0.9674940403900683, 'colsample_bytree': 0.5283504673136102, 'reg_alpha': 0.9252727274631614, 'reg_lambda': 2.8628112610835394, 'gamma': 3.041127826521034}
#
# --- Treinando: SANB11.SA ---
# Melhor Score: 100.00%
# Melhores Parâmetros: {'n_estimators': 412, 'max_depth': 3, 'learning_rate': 0.2840974810916428, 'subsample': 0.5112723570193123, 'colsample_bytree': 0.5394431561406776, 'reg_alpha': 2.059406098147545, 'reg_lambda': 8.217703032386096, 'gamma': 4.685680592361908}
#
# --- Treinando: VIVT3.SA ---
# Melhor Score: 61.11%
# Melhores Parâmetros: {'n_estimators': 477, 'max_depth': 3, 'learning_rate': 0.2962175384456174, 'subsample': 0.5925010785411842, 'colsample_bytree': 0.5604031946859691, 'reg_alpha': 6.071311618371244, 'reg_lambda': 8.9043610894864, 'gamma': 0.2928660999606436}
#
# --- Treinando: SBSP3.SA ---
# Melhor Score: 81.25%
# Melhores Parâmetros: {'n_estimators': 395, 'max_depth': 7, 'learning_rate': 0.10584859909443865, 'subsample': 0.5272280881806164, 'colsample_bytree': 0.5775727275147631, 'reg_alpha': 9.31806783361536, 'reg_lambda': 8.940172488639094, 'gamma': 0.016686127096322223}
#
# --- Treinando: BBSE3.SA ---
# Melhor Score: 100.00%
# Melhores Parâmetros: {'n_estimators': 318, 'max_depth': 3, 'learning_rate': 0.26769079684419445, 'subsample': 0.933806451400683, 'colsample_bytree': 0.9558102461188452, 'reg_alpha': 5.790859651920252, 'reg_lambda': 9.110813343222178, 'gamma': 0.6864937020363704}
#
# --- Treinando: B3SA3.SA ---
# Melhor Score: 56.76%
# Melhores Parâmetros: {'n_estimators': 165, 'max_depth': 8, 'learning_rate': 0.18570585477638407, 'subsample': 0.9311464267349122, 'colsample_bytree': 0.6872629655105528, 'reg_alpha': 0.5158908996390617, 'reg_lambda': 3.353665002389504, 'gamma': 0.36496380230592523}
#
# --- Treinando: SUZB3.SA ---
# Melhor Score: 100.00%
# Melhores Parâmetros: {'n_estimators': 370, 'max_depth': 5, 'learning_rate': 0.01048761116843453, 'subsample': 0.7062726713007544, 'colsample_bytree': 0.796319841892172, 'reg_alpha': 4.131538101637599, 'reg_lambda': 4.229744297963249, 'gamma': 1.4944269421516387}
#
# --- Treinando: CPFE3.SA ---
# Melhor Score: 54.55%
# Melhores Parâmetros: {'n_estimators': 180, 'max_depth': 5, 'learning_rate': 0.1827956351142192, 'subsample': 0.643733713005617, 'colsample_bytree': 0.6106648738505215, 'reg_alpha': 2.6315813074573056, 'reg_lambda': 3.8582384433235353, 'gamma': 3.3235177527820112}
#
# --- Treinando: TIMS3.SA ---
# Melhor Score: 84.21%
# Melhores Parâmetros: {'n_estimators': 327, 'max_depth': 4, 'learning_rate': 0.2554245153805472, 'subsample': 0.6232705424578938, 'colsample_bytree': 0.6368287253496632, 'reg_alpha': 0.26582995422626565, 'reg_lambda': 5.218882838859037, 'gamma': 1.1573248041515234}
#
# --- Treinando: EQTL3.SA ---
# Melhor Score: 80.00%
# Melhores Parâmetros: {'n_estimators': 167, 'max_depth': 7, 'learning_rate': 0.13625513230194916, 'subsample': 0.7205505780211399, 'colsample_bytree': 0.6747123521031099, 'reg_alpha': 1.324100848693993, 'reg_lambda': 3.844674785577426, 'gamma': 3.221422788657975}
#
# --- Treinando: RENT3.SA ---
# Melhor Score: 64.52%
# Melhores Parâmetros: {'n_estimators': 496, 'max_depth': 3, 'learning_rate': 0.039964167744491914, 'subsample': 0.5089931994572203, 'colsample_bytree': 0.8958639870158422, 'reg_alpha': 0.6457929370359335, 'reg_lambda': 0.3832743663734204, 'gamma': 0.5204221779434695}
#
# --- Treinando: RADL3.SA ---
# Melhor Score: 73.91%
# Melhores Parâmetros: {'n_estimators': 474, 'max_depth': 10, 'learning_rate': 0.19176195396472848, 'subsample': 0.5159045125491515, 'colsample_bytree': 0.8574551959561738, 'reg_alpha': 0.32129059548716166, 'reg_lambda': 3.8785746690372505, 'gamma': 2.338776818508539}
#
# --- Treinando: NEOE3.SA ---
# Melhor Score: 50.00%
# Melhores Parâmetros: {'n_estimators': 113, 'max_depth': 7, 'learning_rate': 0.2036440016257229, 'subsample': 0.6088096409446855, 'colsample_bytree': 0.7720391377992056, 'reg_alpha': 8.14047420265724, 'reg_lambda': 7.331200736057983, 'gamma': 1.3142796927203308}
#
# --- Treinando: ENEV3.SA ---
# Melhor Score: 100.00%
# Melhores Parâmetros: {'n_estimators': 92, 'max_depth': 4, 'learning_rate': 0.14505043654584615, 'subsample': 0.7068010185016964, 'colsample_bytree': 0.9768090743374108, 'reg_alpha': 2.983868407078403, 'reg_lambda': 7.220627637263923, 'gamma': 4.439086125048145}
#
# --- Treinando: GGBR3.SA ---
# Melhor Score: 90.91%
# Melhores Parâmetros: {'n_estimators': 77, 'max_depth': 7, 'learning_rate': 0.263549028336676, 'subsample': 0.683995638303261, 'colsample_bytree': 0.8393196116544115, 'reg_alpha': 0.05610379969482409, 'reg_lambda': 7.998156889536038, 'gamma': 0.13436673575726799}
#
# --- Treinando: EGIE3.SA ---
# Melhor Score: 75.00%
# Melhores Parâmetros: {'n_estimators': 500, 'max_depth': 6, 'learning_rate': 0.22880809356189047, 'subsample': 0.5255683099736792, 'colsample_bytree': 0.589099383456901, 'reg_alpha': 1.845578200802716, 'reg_lambda': 2.701599645263304, 'gamma': 3.8792985899881405}
#
# --- Treinando: CMIG4.SA ---
# Melhor Score: 66.67%
# Melhores Parâmetros: {'n_estimators': 483, 'max_depth': 6, 'learning_rate': 0.15269958779027828, 'subsample': 0.6274567384674986, 'colsample_bytree': 0.5672794738893776, 'reg_alpha': 2.6192642392974226, 'reg_lambda': 0.7679468828269005, 'gamma': 0.003863902662576968}
#
# --- Treinando: PRIO3.SA ---
# Melhor Score: 54.35%
# Melhores Parâmetros: {'n_estimators': 145, 'max_depth': 3, 'learning_rate': 0.2898748593193232, 'subsample': 0.8229419934533828, 'colsample_bytree': 0.5538555095244021, 'reg_alpha': 1.3693278988257522, 'reg_lambda': 7.089557990752379, 'gamma': 2.453093558333327}
#
# --- Treinando: VBBR3.SA ---
# Melhor Score: 77.78%
# Melhores Parâmetros: {'n_estimators': 490, 'max_depth': 3, 'learning_rate': 0.18356806995566274, 'subsample': 0.5888582800516072, 'colsample_bytree': 0.5179788672718849, 'reg_alpha': 1.236148401016575, 'reg_lambda': 8.250817647912644, 'gamma': 0.9738538149989764}
#
# --- Treinando: RAIL3.SA ---
# Melhor Score: 100.00%
# Melhores Parâmetros: {'n_estimators': 246, 'max_depth': 6, 'learning_rate': 0.1668510800975773, 'subsample': 0.73648043741349, 'colsample_bytree': 0.9937823994136132, 'reg_alpha': 5.393717023918204, 'reg_lambda': 7.863859480013126, 'gamma': 3.6115754933917827}
#
# --- Treinando: TOTS3.SA ---
# Melhor Score: 53.66%
# Melhores Parâmetros: {'n_estimators': 308, 'max_depth': 6, 'learning_rate': 0.1263156598903095, 'subsample': 0.9726559248875388, 'colsample_bytree': 0.6310853033831028, 'reg_alpha': 0.014271239699667593, 'reg_lambda': 5.114998732416284, 'gamma': 1.0446303989770338}
#
# --- Treinando: ENGI11.SA ---
# Melhor Score: 60.98%
# Melhores Parâmetros: {'n_estimators': 408, 'max_depth': 7, 'learning_rate': 0.18189916078183135, 'subsample': 0.6592503648970898, 'colsample_bytree': 0.7100693920278426, 'reg_alpha': 5.420591550159094, 'reg_lambda': 2.041141271573859, 'gamma': 4.978221221299925}
#
# --- Treinando: KLBN11.SA ---
# Melhor Score: 100.00%
# Melhores Parâmetros: {'n_estimators': 304, 'max_depth': 3, 'learning_rate': 0.08086913135925433, 'subsample': 0.8635058155034002, 'colsample_bytree': 0.996897539236461, 'reg_alpha': 6.758732776597326, 'reg_lambda': 7.337636432195968, 'gamma': 1.0098162966572881}
#
# --- Treinando: UGPA3.SA ---
# Melhor Score: 100.00%
# Melhores Parâmetros: {'n_estimators': 498, 'max_depth': 5, 'learning_rate': 0.299540253300502, 'subsample': 0.7321818268499645, 'colsample_bytree': 0.915371831667211, 'reg_alpha': 4.584635954547451, 'reg_lambda': 3.994634679841467, 'gamma': 0.476416675575138}
#
# --- Treinando: CSAN3.SA ---
# Melhor Score: 57.14%
# Melhores Parâmetros: {'n_estimators': 465, 'max_depth': 7, 'learning_rate': 0.26218598163299167, 'subsample': 0.6226848611869267, 'colsample_bytree': 0.6245604731449381, 'reg_alpha': 9.444327495044325, 'reg_lambda': 8.544883888549954, 'gamma': 0.7455117762530699}
#
# --- Treinando: CSMG3.SA ---
# Melhor Score: 58.06%
# Melhores Parâmetros: {'n_estimators': 140, 'max_depth': 7, 'learning_rate': 0.18484934460007274, 'subsample': 0.8373386930957595, 'colsample_bytree': 0.9748982142798717, 'reg_alpha': 2.905150913232967, 'reg_lambda': 2.358056532946483, 'gamma': 1.636521893900722}
#
# --- Treinando: GOAU4.SA ---
# Melhor Score: 58.62%
# Melhores Parâmetros: {'n_estimators': 233, 'max_depth': 8, 'learning_rate': 0.23003324234812594, 'subsample': 0.5319371257428142, 'colsample_bytree': 0.9715439761642833, 'reg_alpha': 4.034874197839163, 'reg_lambda': 0.34307459520363714, 'gamma': 0.41343033207726876}
#
# --- Treinando: HYPE3.SA ---
# Melhor Score: 90.91%
# Melhores Parâmetros: {'n_estimators': 57, 'max_depth': 7, 'learning_rate': 0.08804312235674597, 'subsample': 0.8901599975264866, 'colsample_bytree': 0.6619027721894835, 'reg_alpha': 2.615337044646096, 'reg_lambda': 4.069426768549651, 'gamma': 4.618615498908304}
#
# --- Treinando: ALOS3.SA ---
# Melhor Score: 100.00%
# Melhores Parâmetros: {'n_estimators': 338, 'max_depth': 8, 'learning_rate': 0.12254940114049247, 'subsample': 0.7831944726333446, 'colsample_bytree': 0.6831631778129584, 'reg_alpha': 7.292424968159545, 'reg_lambda': 4.294513340762562, 'gamma': 0.6515849591369203}
#
# --- Treinando: MULT3.SA ---
# Melhor Score: 50.00%
# Melhores Parâmetros: {'n_estimators': 391, 'max_depth': 10, 'learning_rate': 0.26348428510630617, 'subsample': 0.5673707651962708, 'colsample_bytree': 0.7083644835109583, 'reg_alpha': 4.707327419031974, 'reg_lambda': 5.631260539924854, 'gamma': 1.2162437131364379}
#
# --- Treinando: TAEE11.SA ---
# Melhor Score: 71.43%
# Melhores Parâmetros: {'n_estimators': 475, 'max_depth': 10, 'learning_rate': 0.2694714453143436, 'subsample': 0.5462725436411541, 'colsample_bytree': 0.5431216698889706, 'reg_alpha': 5.685267111025507, 'reg_lambda': 8.287628156641487, 'gamma': 0.16912919433103732}
#
# --- Treinando: LREN3.SA ---
# Melhor Score: 61.11%
# Melhores Parâmetros: {'n_estimators': 359, 'max_depth': 4, 'learning_rate': 0.17969657706269432, 'subsample': 0.8231286696484543, 'colsample_bytree': 0.5543528720540654, 'reg_alpha': 0.011638215021917198, 'reg_lambda': 5.794304626282528, 'gamma': 2.881522374011499}
#
# --- Treinando: REDE3.SA ---
# Melhor Score: 80.00%
# Melhores Parâmetros: {'n_estimators': 376, 'max_depth': 7, 'learning_rate': 0.1849144464960345, 'subsample': 0.6449596390983506, 'colsample_bytree': 0.6068103614678692, 'reg_alpha': 5.333033710213031, 'reg_lambda': 0.592541451072195, 'gamma': 3.222671438527503}
#
# --- Treinando: CSNA3.SA ---
# Melhor Score: 100.00%
# Melhores Parâmetros: {'n_estimators': 127, 'max_depth': 3, 'learning_rate': 0.2993655341928152, 'subsample': 0.9406871198280089, 'colsample_bytree': 0.5928779831876068, 'reg_alpha': 4.723707748151572, 'reg_lambda': 4.227477335825394, 'gamma': 1.6499632178030592}
#
# --- Treinando: CYRE3.SA ---
# Melhor Score: 100.00%
# Melhores Parâmetros: {'n_estimators': 135, 'max_depth': 4, 'learning_rate': 0.07470714445212844, 'subsample': 0.575356151313725, 'colsample_bytree': 0.6161089059744642, 'reg_alpha': 2.567397755875195, 'reg_lambda': 9.119593360289072, 'gamma': 1.320337279553444}
#
# --- Treinando: ALUP11.SA ---
# Melhor Score: 51.43%
# Melhores Parâmetros: {'n_estimators': 244, 'max_depth': 8, 'learning_rate': 0.212442953827566, 'subsample': 0.5039472862078946, 'colsample_bytree': 0.6731558791479041, 'reg_alpha': 0.27027380825458036, 'reg_lambda': 0.12770939888494226, 'gamma': 1.7042557372931801}
#
# --- Treinando: FLRY3.SA ---
# Melhor Score: 66.67%
# Melhores Parâmetros: {'n_estimators': 162, 'max_depth': 5, 'learning_rate': 0.10915317452052187, 'subsample': 0.8923495284162031, 'colsample_bytree': 0.8124582329866658, 'reg_alpha': 6.414506200509384, 'reg_lambda': 4.06693381051258, 'gamma': 2.603719583637175}
#
# --- Treinando: USIM5.SA ---
# Melhor Score: 56.41%
# Melhores Parâmetros: {'n_estimators': 77, 'max_depth': 6, 'learning_rate': 0.06190203908435943, 'subsample': 0.8596003198718365, 'colsample_bytree': 0.9234337764745468, 'reg_alpha': 0.4860731273102754, 'reg_lambda': 8.485779738534674, 'gamma': 2.897903866797222}
#
# --- Treinando: BRAP4.SA ---
# Melhor Score: 65.22%
# Melhores Parâmetros: {'n_estimators': 393, 'max_depth': 4, 'learning_rate': 0.13480451589223094, 'subsample': 0.6232665594925638, 'colsample_bytree': 0.6777097079609301, 'reg_alpha': 0.05873873918837136, 'reg_lambda': 1.7106269557145863, 'gamma': 2.398867468531445}
#
# --- Treinando: HAPV3.SA ---
# Melhor Score: 55.81%
# Melhores Parâmetros: {'n_estimators': 375, 'max_depth': 6, 'learning_rate': 0.25607032818864084, 'subsample': 0.5409080836533271, 'colsample_bytree': 0.9895459753644137, 'reg_alpha': 2.838537622585504, 'reg_lambda': 7.323398528780504, 'gamma': 0.18618576017845834}
#
# --- Treinando: SLCE3.SA ---
# Melhor Score: 79.31%
# Melhores Parâmetros: {'n_estimators': 117, 'max_depth': 5, 'learning_rate': 0.2396984398655692, 'subsample': 0.6826445074021619, 'colsample_bytree': 0.8563551380285241, 'reg_alpha': 2.1639572056450795, 'reg_lambda': 3.8826711563903626, 'gamma': 0.4602923823108024}
#
# --- Treinando: MGLU3.SA ---
# Melhor Score: 44.44%
# Melhores Parâmetros: {'n_estimators': 52, 'max_depth': 5, 'learning_rate': 0.24919547897527353, 'subsample': 0.9976117586501536, 'colsample_bytree': 0.7868137842043782, 'reg_alpha': 2.2950995579019344, 'reg_lambda': 5.365119867459847, 'gamma': 1.8139454144491478}
#
# --- Treinando: COGN3.SA ---
# Melhor Score: 77.78%
# Melhores Parâmetros: {'n_estimators': 151, 'max_depth': 8, 'learning_rate': 0.13895131505526487, 'subsample': 0.671103263463192, 'colsample_bytree': 0.920202603725376, 'reg_alpha': 6.15095819571087, 'reg_lambda': 2.4053433257641887, 'gamma': 2.5180088155070264}
#
# --- Treinando: BRKM5.SA ---
# Melhor Score: 63.64%
# Melhores Parâmetros: {'n_estimators': 216, 'max_depth': 9, 'learning_rate': 0.04889748159828136, 'subsample': 0.7768204444011932, 'colsample_bytree': 0.9105203933066313, 'reg_alpha': 3.0184295383932005, 'reg_lambda': 2.8845604044455566, 'gamma': 4.04670568562293}
#
# --- Treinando: BEEF3.SA ---
# Melhor Score: 52.27%
# Melhores Parâmetros: {'n_estimators': 237, 'max_depth': 3, 'learning_rate': 0.0964469978847611, 'subsample': 0.9996392260334646, 'colsample_bytree': 0.5130285005579148, 'reg_alpha': 0.32919901123963946, 'reg_lambda': 0.2713504362375181, 'gamma': 0.1748845065722997}
#
# --- Treinando: MRVE3.SA ---
# Melhor Score: 100.00%
# Melhores Parâmetros: {'n_estimators': 379, 'max_depth': 3, 'learning_rate': 0.04478758766174309, 'subsample': 0.5447765628458041, 'colsample_bytree': 0.7650934624222029, 'reg_alpha': 1.8940208129987797, 'reg_lambda': 7.431398429839944, 'gamma': 4.203642288114455}
#
# --- Treinando: DXCO3.SA ---
# Melhor Score: 55.88%
# Melhores Parâmetros: {'n_estimators': 463, 'max_depth': 4, 'learning_rate': 0.1333512612752405, 'subsample': 0.5732105492012363, 'colsample_bytree': 0.5354368618288149, 'reg_alpha': 0.42843037773252035, 'reg_lambda': 0.7276625859099252, 'gamma': 3.8430452359107434}
#
# --- Treinando: IRBR3.SA ---
# Melhor Score: 75.00%
# Melhores Parâmetros: {'n_estimators': 263, 'max_depth': 3, 'learning_rate': 0.109396923160197, 'subsample': 0.5526544116500911, 'colsample_bytree': 0.8691911194445924, 'reg_alpha': 2.9423611072578777, 'reg_lambda': 0.6006161393955176, 'gamma': 2.1124283955942142}
#
# --- Treinando: EZTC3.SA ---
# Melhor Score: 100.00%
# Melhores Parâmetros: {'n_estimators': 270, 'max_depth': 5, 'learning_rate': 0.103662627511418, 'subsample': 0.8644305482125937, 'colsample_bytree': 0.5889703055011914, 'reg_alpha': 1.6728382068477265, 'reg_lambda': 4.85948958235338, 'gamma': 2.4181955805453477}
#
# --- Treinando: YDUQ3.SA ---
# Melhor Score: 100.00%
# Melhores Parâmetros: {'n_estimators': 200, 'max_depth': 5, 'learning_rate': 0.17837081644609917, 'subsample': 0.9244983618885725, 'colsample_bytree': 0.9152934694171764, 'reg_alpha': 5.849355313045543, 'reg_lambda': 4.69467934443688, 'gamma': 1.2788699580967033}
#
# --- Treinando: AZUL4.SA ---
# Melhor Score: 60.00%
# Melhores Parâmetros: {'n_estimators': 290, 'max_depth': 5, 'learning_rate': 0.2750634495278664, 'subsample': 0.6689761292529454, 'colsample_bytree': 0.5045465061943541, 'reg_alpha': 3.0022181032664776, 'reg_lambda': 2.6215043846836865, 'gamma': 4.343252191761778}

# %%
joblib.dump(modelosA, '../modelos/ModelosA.pkl')
print("Arquivo mestre salvo com sucesso.")
# Out:
# Arquivo mestre salvo com sucesso.

# %%
treino = {}

for ticker, df in features_A.items():

    split = int(len(df) * 0.8)
    
    dfcut = df.iloc[split:].copy()
    
    treino[ticker] = dfcut

joblib.dump(treino, '../FeaturesA.pkl')
# Out:
# ['../FeaturesA.pkl']
